# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("uciml/breast-cancer-wisconsin-data")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 48.6k/48.6k [00:00<00:00, 43.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/uciml/breast-cancer-wisconsin-data/versions/2

# %%
import pandas as pd
df = pd.read_csv(path + "/data.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Set options to display all columns and rows
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df = df.drop(columns=['Unnamed: 32'])

# %%
print(df.head())
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
features = df.drop('diagnosis', axis=1)
target = df['diagnosis']

# %%
target = target.map({'M':1, 'B':0})

# %%
target.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %%
target.tail()
# Out:
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, dtype: int64

# %%
features.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424        21.56         22.39          142.00     1479.0
# 565  926682        20.13         28.25          131.20     1261.0
# 566  926954        16.60         28.08          108.30      858.1
# 567  927241        20.60         29.33          140.10     1265.0
# 568   92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
features = features.drop(columns=['id'])

# %%
features.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (455, 30)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical


model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                     │ (None, 32)                  │             992 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 10)                  │             330 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,333 (5.21 KB)
#  Trainable params: 1,333 (5.21 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=30, batch_size=8, validation_split=0.2)
# Out:
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5813 - loss: 3.9313 - val_accuracy: 0.5934 - val_loss: 2.1241
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6400 - loss: 1.1048 - val_accuracy: 0.7582 - val_loss: 0.9168
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6805 - loss: 0.7796 - val_accuracy: 0.8571 - val_loss: 0.5706
# Epoch 4/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8377 - loss: 0.5139 - val_accuracy: 0.8791 - val_loss: 0.4561
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8858 - loss: 0.2864 - val_accuracy: 0.7802 - val_loss: 0.8517
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7597 - loss: 0.6720 - val_accuracy: 0.8681 - val_loss: 0.3959
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9218 - loss: 0.2085 - val_accuracy: 0.8791 - val_loss: 0.3203
# Epoch 8/30
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
# Evaluate the model on test data
loss, accuracy = model.evaluate(X_test, y_test)

# Print out the test accuracy and loss
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test Loss: {loss:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9446 - loss: 0.1495
# Test Accuracy: 0.9474
# Test Loss: 0.1456

# %%
X_test.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 204        12.47         18.60           81.09      481.9          0.09965
# 70         18.94         21.31          123.60     1130.0          0.09009
# 131        15.46         19.48          101.70      748.9          0.10920
# 431        12.40         17.68           81.47      467.8          0.10540
# 540        11.54         14.44           74.65      402.9          0.09984
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 204            0.1058         0.08005              0.03821         0.1925
# 70             0.1029         0.10800              0.07951         0.1582
# 131            0.1223         0.14660              0.08087         0.1931
# 431            0.1316         0.07741              0.02799         0.1811
# 540            0.1120         0.06737              0.02594         0.1818
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# ...

# %%
print(y_test.iloc[20])
# Out:
# 1

# %%
prediction = model.predict(X_test)

for i in range(len(prediction)):
    if prediction[i] > 0.5:
      prediction[i] = 1
    else:
      prediction[i] = 0

print(prediction[20])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# [1.]

# %%
# doesn't have
test_data = [[8.888,14.64,58.79,244,0.09783,0.1531,0.08606,0.02872,0.1902,0.0898,0.5262,0.8522,3.168,25.44,0.01721,0.09368,0.05671,0.01766,0.02541,0.02193,9.733,15.67,62.56,284.4,0.1207,0.2436,0.1434,0.04786,0.2254,0.1084]]
# doesn't have
test_data_2=[19.69, 21.25, 130.0, 1203.0, 0.1096, 0.1599, 0.1974, 0.1279, 0.2069, 0.05999, 0.7456, 0.7869, 4.585, 94.03, 0.00615, 0.04006, 0.03832, 0.02058, 0.0225, 0.004571, 22.15, 30.73, 149.7, 1535.0, 0.1444, 0.4245, 0.4504, 0.243, 0.3613, 0.08758]
# has
test_data_cancer = [
    [
        20.29,  # radius_mean
        14.34,  # texture_mean
        135.1,  # perimeter_mean
        1297,   # area_mean
        0.1003, # smoothness_mean
        0.1328, # compactness_mean
        0.198,  # concavity_mean
        0.1043, # concave points_mean
        0.1809, # symmetry_mean
        0.05883, # fractal_dimension_mean
        0.7572, # radius_se
        0.7813, # texture_se
        5.438,  # perimeter_se
        94.44,  # area_se
        0.00634, # smoothness_se
        0.04994, # compactness_se
        0.05373, # concavity_se
        0.01587, # concave points_se
        0.03003, # symmetry_se
        0.006193, # fractal_dimension_se
        24.29,   # radius_worst
        16.55,   # texture_worst
        158.8,   # perimeter_worst
        1956,    # area_worst
        0.1238,  # smoothness_worst
        0.1866,  # compactness_worst
        0.2416,  # concavity_worst
        0.186,   # concave points_worst
        0.275,   # symmetry_worst
        0.08902  # fractal_dimension_worst
    ]
]


test_data_benign = [
    [
        9.029,  # radius_mean
        13.9,   # texture_mean
        59.7,   # perimeter_mean
        250.5,  # area_mean
        0.0732, # smoothness_mean
        0.0286, # compactness_mean
        0.0223, # concavity_mean
        0.0102, # concave points_mean
        0.1541, # symmetry_mean
        0.06025, # fractal_dimension_mean
        0.2562, # radius_se
        0.3487, # texture_se
        1.236,  # perimeter_se
        16.74,  # area_se
        0.00434, # smoothness_se
        0.00732, # compactness_se
        0.00719, # concavity_se
        0.002145, # concave points_se
        0.02231, # symmetry_se
        0.002905, # fractal_dimension_se
        10.29,   # radius_worst
        14.67,   # texture_worst
        65.56,   # perimeter_worst
        300.4,   # area_worst
        0.0894,  # smoothness_worst
        0.0732,  # compactness_worst
        0.0567,  # concavity_worst
        0.0277,  # concave points_worst
        0.204,   # symmetry_worst
        0.07012  # fractal_dimension_worst
    ]
]

# %%
import numpy as np

# Convert the test data to a NumPy array
test_data_array =  np.array(test_data_benign)

# Make predictions using the trained model
prediction = model.predict(test_data_array)
for i in range(len(prediction)):
    if prediction[i] > 0.5:
      prediction[i] = 1
      print(prediction[i],"has breast canser")
    else:
      prediction[i] = 0
      print(prediction[i],"doesn't have breast canser")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [0.] doesn't have breast canser

# %%
model.save('my_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
